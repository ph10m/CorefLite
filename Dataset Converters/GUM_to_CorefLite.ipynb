# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from tollef_conll_converter import GumConverter

# %%
datadir = "../../../data/COREFERENCE_RESOLUTION/gum_news"
outdir = "../../../data/COREFERENCE_RESOLUTION/gum_news.coreflite"

gumconv = GumConverter(datadir, outdir, fields=["id", "word", "coref"])

# %%
gumconv.run()
# Out:
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_asylum.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_clock.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_crane.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_defector.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_election.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_expo.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_flag.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_hackers.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_homeopathic.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_ie9.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_imprisoned.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_iodine.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_korea.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_news\GUM_news_lanterns.conll
# ...

# %%
datadir = "../../../data/COREFERENCE_RESOLUTION/gum_conll"
outdir = "../../../data/COREFERENCE_RESOLUTION/gum.coreflite"

gumconv = GumConverter(datadir, outdir, fields=["id", "word", "coref"])
gumconv.run()
# Out:
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_art.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_census.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_discrimination.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_eegimaa.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_enjambment.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_epistemic.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_exposure.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_games.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_huh.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_implicature.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_librarians.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_lighting.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_conll\GUM_academic_mutation.conll
# ...

# %%
datadir = "../../../data/COREFERENCE_RESOLUTION/gum_others"
outdir = "../../../data/COREFERENCE_RESOLUTION/gum_others.coreflite"

gumconv = GumConverter(datadir, outdir, fields=["id", "word", "coref"])
gumconv.run()
# Out:
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_art.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_census.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_discrimination.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_eegimaa.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_enjambment.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_epistemic.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_exposure.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_games.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_huh.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_implicature.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_librarians.conll
# ../../../data/COREFERENCE_RESOLUTION/gum_others\GUM_academic_lighting.conll
# ...
